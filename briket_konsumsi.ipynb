# %%
import pandas 
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
data_consumtion = pandas.read_excel("briket_konsumsi.xlsx")

X = data_consumtion[['Periode']]
y = data_consumtion[['Konsumsi']]

# %%
regression = linear_model.LinearRegression()
model = regression.fit(X.values,y)
m = float(regression.coef_[0])
b = float(regression.intercept_)
equation = f" y ={b:.2f} + {m:.2f} x"

# %%
model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

plt.scatter(X.values, y, color='blue', label='Data Briket')
plt.plot(X.values, y_pred, color='red', label='Regresi Linear')
plt.xlabel('Periode')
plt.ylabel('Konsumsi Briket (Seribu ton )')
plt.title('Regresi Linier Konsumsi Briket')
plt.legend()
plt.show()
